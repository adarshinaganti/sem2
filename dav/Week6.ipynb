# %% [markdown]
# # Week 6

# %% [markdown]
# **Name:** I Adarsh *(PG-12)*<br>
# **Registration Number:** 240905294<br>
# **Date:** 25/02/2025

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Program 1
# For the MTCARS dataset, answer the specified questions with summarization and effective visuals.

# %%
mt = pd.read_csv('mtcars.csv')
mt.set_index('model', inplace=True)
mt.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# model
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# model
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %% [markdown]
# Categorize the cars based on the number of gears in the cars. How many cars are there in each type?

# %%
mt_g3 = mt.where(mt['gear'] == 3).dropna()
mt_g4 = mt.where(mt['gear'] == 4).dropna()

# %%
mt_g3.head()
# Out:
#                     mpg  cyl   disp     hp  drat     wt   qsec   vs   am  \
# model
# Hornet 4 Drive     21.4  6.0  258.0  110.0  3.08  3.215  19.44  1.0  0.0
# Hornet Sportabout  18.7  8.0  360.0  175.0  3.15  3.440  17.02  0.0  0.0
# Valiant            18.1  6.0  225.0  105.0  2.76  3.460  20.22  1.0  0.0
# Duster 360         14.3  8.0  360.0  245.0  3.21  3.570  15.84  0.0  0.0
# Merc 450SE         16.4  8.0  275.8  180.0  3.07  4.070  17.40  0.0  0.0
#
#                    gear  carb
# model
# Hornet 4 Drive      3.0   1.0
# Hornet Sportabout   3.0   2.0
# Valiant             3.0   1.0
# Duster 360          3.0   4.0
# Merc 450SE          3.0   3.0

# %%
mt_g4.head()
# Out:
#                 mpg  cyl   disp     hp  drat     wt   qsec   vs   am  gear  \
# model
# Mazda RX4      21.0  6.0  160.0  110.0  3.90  2.620  16.46  0.0  1.0   4.0
# Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02  0.0  1.0   4.0
# Datsun 710     22.8  4.0  108.0   93.0  3.85  2.320  18.61  1.0  1.0   4.0
# Merc 240D      24.4  4.0  146.7   62.0  3.69  3.190  20.00  1.0  0.0   4.0
# Merc 230       22.8  4.0  140.8   95.0  3.92  3.150  22.90  1.0  0.0   4.0
#
#                carb
# model
# Mazda RX4       4.0
# Mazda RX4 Wag   4.0
# Datsun 710      1.0
# Merc 240D       2.0
# Merc 230        2.0

# %% [markdown]
# What is the relationship between fuel efficiency and the number of gears in the car?

# %%
mt_g3['mpg'].plot(kind='bar', alpha=0.5, label='gear = 3', legend=True)
# Out:
# <Axes: xlabel='model'>
